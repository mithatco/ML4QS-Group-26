# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.utils import class_weight
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

import matplotlib.pyplot as plt


# Load the dataset
df = pd.read_csv('Processed Data/Instances Imputed.csv', delimiter='\t')

# Drop non-feature columns
X = df.drop(columns=['Stress Level', 'Date/Time'])
y = df['Stress Level']

# Encode target labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Normalize the features
scaler = MinMaxScaler()#StandardScaler()
X_scaled = scaler.fit_transform(X)

split_index_train = int(0.8 * len(X_scaled))
split_index_val = int(0.9 * len(X_scaled))

X_train, X_val, X_test = X_scaled[:split_index_train], X_scaled[split_index_train:split_index_val],X_scaled[split_index_val:]
y_train, y_val, y_test = y_encoded[:split_index_train], y_encoded[split_index_train:split_index_val],y_encoded[split_index_val:]

# %%
import numpy as np
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Dense, LayerNormalization, Dropout, MultiHeadAttention, Add, Flatten, Lambda
from keras.optimizers import Adam
from sklearn.utils import class_weight
from sklearn.metrics import precision_score, recall_score, f1_score

# Transformer Block
def transformer_block(inputs, head_size, num_heads, ff_dim, dropout=0):
    attn_output = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
    attn_output = Dropout(dropout)(attn_output)
    out1 = Add()([inputs, attn_output])
    out1 = LayerNormalization(epsilon=1e-6)(out1)
    
    ffn_output = Dense(ff_dim, activation="relu")(out1)
    ffn_output = Dropout(dropout)(ffn_output)
    
    ffn_output = Dense(inputs.shape[-1], activation="relu")(ffn_output)  # Ensure same shape as input
    out2 = Add()([out1, ffn_output])
    return LayerNormalization(epsilon=1e-6)(out2)

# Build the model
input_shape = (13,)
inputs = Input(shape=input_shape)

# Expand dimensions for multi-head attention
x = Dense(64)(inputs)
x = Lambda(lambda x: tf.expand_dims(x, axis=1))(x)  # Add a sequence dimension

# Transformer layers
x = transformer_block(x, head_size=64, num_heads=4, ff_dim=128, dropout=0.1)
x = transformer_block(x, head_size=64, num_heads=4, ff_dim=128, dropout=0.1)

# Flatten and add classification head
x = Flatten()(x)
x = Dense(64, activation="relu")(x)
x = Dropout(0.1)(x)
x = Dense(32, activation="relu")(x)
x = Dropout(0.1)(x)
outputs = Dense(3, activation="softmax")(x)

# Compile the model
model = Model(inputs, outputs)

# Calculate class weights
class_weights = dict(enumerate(class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)))

# Compile the model without specifying accuracy
model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy')

# Model summary
model.summary()

# Custom Metrics Callback
class Metrics(tf.keras.callbacks.Callback):
    def __init__(self, validation_data):
        super().__init__()
        self.validation_data = validation_data

    def on_epoch_end(self, epoch, logs=None):
        val_predict = np.argmax(self.model.predict(self.validation_data[0]), axis=1)
        val_targ = self.validation_data[1]
        _val_precision = precision_score(val_targ, val_predict, average=None, zero_division=0)
        _val_recall = recall_score(val_targ, val_predict, average=None, zero_division=0)
        _val_f1 = f1_score(val_targ, val_predict, average=None, zero_division=0)
        for i, (p, r, f) in enumerate(zip(_val_precision, _val_recall, _val_f1)):
            print(f" — Class {i} — val_precision: {p:.4f} — val_recall: {r:.4f} — val_f1: {f:.4f}")
# Out:
# Model: "functional_17"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_18      │ (None, 13)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_40 (Dense)    │ (None, 64)        │        896 │ input_layer_18[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 1, 64)     │          0 │ dense_40[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 1, 64)     │     66,368 │ lambda[0][0],     │
# │ (MultiHeadAttentio… │                   │            │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_49          │ (None, 1, 64)     │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 1, 64)     │          0 │ lambda[0][0],     │
# │                     │                   │            │ dropout_49[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 1, 64)     │        128 │ add_26[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_41 (Dense)    │ (None, 1, 128)    │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_50          │ (None, 1, 128)    │          0 │ dense_41[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_42 (Dense)    │ (None, 1, 64)     │      8,256 │ dropout_50[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 1, 64)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_42[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 1, 64)     │        128 │ add_27[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 1, 64)     │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_52          │ (None, 1, 64)     │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_28 (Add)        │ (None, 1, 64)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_52[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 1, 64)     │        128 │ add_28[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_43 (Dense)    │ (None, 1, 128)    │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_53          │ (None, 1, 128)    │          0 │ dense_43[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_44 (Dense)    │ (None, 1, 64)     │      8,256 │ dropout_53[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_29 (Add)        │ (None, 1, 64)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_44[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 1, 64)     │        128 │ add_29[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 64)        │          0 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_45 (Dense)    │ (None, 64)        │      4,160 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_54          │ (None, 64)        │          0 │ dense_45[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_46 (Dense)    │ (None, 32)        │      2,080 │ dropout_54[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_55          │ (None, 32)        │          0 │ dense_46[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_47 (Dense)    │ (None, 3)         │         99 │ dropout_55[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 173,635 (678.26 KB)
#  Trainable params: 173,635 (678.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Initialize the custom metric callback with validation data
metrics = Metrics(validation_data=(X_val, y_val))

# Train the model with the custom metrics callback and class weights
history = model.fit(X_train, y_train, epochs=50, batch_size=16, shuffle=True, validation_data=(X_val, y_val), verbose=1, callbacks=[metrics], class_weight=class_weights)
# Out:
# Epoch 1/50
# /Users/vincent/mambaforge/envs/ml4qs/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (16, 4, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.1631
# /Users/vincent/mambaforge/envs/ml4qs/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 4, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /Users/vincent/mambaforge/envs/ml4qs/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 4, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
#  — Class 0 — val_precision: 0.0000 — val_recall: 0.0000 — val_f1: 0.0000
#  — Class 1 — val_precision: 0.7077 — val_recall: 0.6747 — val_f1: 0.6908
#  — Class 2 — val_precision: 0.1796 — val_recall: 0.3248 — val_f1: 0.2313
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 77s 81ms/step - loss: 1.1631 - val_loss: 1.0548
# Epoch 2/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step ep -
#  — Class 0 — val_precision: 0.1172 — val_recall: 0.7929 — val_f1: 0.2042
#  — Class 1 — val_precision: 0.7241 — val_recall: 0.0175 — val_f1: 0.0341
#  — Class 2 — val_precision: 0.1797 — val_recall: 0.1975 — val_f1: 0.1882
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 65s 75ms/step - loss: 1.0966 - val_loss: 1.1738
# Epoch 3/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step ep
#  — Class 0 — val_precision: 0.0000 — val_recall: 0.0000 — val_f1: 0.0000
#  — Class 1 — val_precision: 0.8140 — val_recall: 0.1165 — val_f1: 0.2038
#  — Class 2 — val_precision: 0.1907 — val_recall: 0.9363 — val_f1: 0.3168
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 74ms/step - loss: 1.1012 - val_loss: 1.1046
# Epoch 4/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep -
#  — Class 0 — val_precision: 0.1386 — val_recall: 0.4697 — val_f1: 0.2140
#  — Class 1 — val_precision: 0.7673 — val_recall: 0.2854 — val_f1: 0.4160
#  — Class 2 — val_precision: 0.1846 — val_recall: 0.3503 — val_f1: 0.2418
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 65s 76ms/step - loss: 1.1048 - val_loss: 1.0755
# Epoch 5/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
#  — Class 0 — val_precision: 0.1296 — val_recall: 0.6061 — val_f1: 0.2135
#  — Class 1 — val_precision: 0.7602 — val_recall: 0.2795 — val_f1: 0.4088
#  — Class 2 — val_precision: 0.1792 — val_recall: 0.1975 — val_f1: 0.1879
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 75ms/step - loss: 1.0895 - val_loss: 1.0931
# Epoch 6/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep
#  — Class 0 — val_precision: 0.1481 — val_recall: 0.0202 — val_f1: 0.0356
#  — Class 1 — val_precision: 0.8031 — val_recall: 0.1730 — val_f1: 0.2847
#  — Class 2 — val_precision: 0.1926 — val_recall: 0.8758 — val_f1: 0.3157
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 83s 97ms/step - loss: 1.0967 - val_loss: 1.0978
# Epoch 7/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/stepep - l
#  — Class 0 — val_precision: 0.1271 — val_recall: 0.2626 — val_f1: 0.1713
#  — Class 1 — val_precision: 0.7461 — val_recall: 0.3619 — val_f1: 0.4874
#  — Class 2 — val_precision: 0.1814 — val_recall: 0.4172 — val_f1: 0.2529
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 65s 76ms/step - loss: 1.1017 - val_loss: 1.0722
# Epoch 8/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1224 — val_recall: 0.9545 — val_f1: 0.2170
#  — Class 1 — val_precision: 0.9080 — val_recall: 0.0657 — val_f1: 0.1226
#  — Class 2 — val_precision: 0.2048 — val_recall: 0.0541 — val_f1: 0.0856
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 75ms/step - loss: 1.0732 - val_loss: 1.1351
# Epoch 9/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep -
#  — Class 0 — val_precision: 0.0769 — val_recall: 0.0253 — val_f1: 0.0380
#  — Class 1 — val_precision: 0.7778 — val_recall: 0.1980 — val_f1: 0.3156
#  — Class 2 — val_precision: 0.1936 — val_recall: 0.8280 — val_f1: 0.3138
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 75ms/step - loss: 1.1007 - val_loss: 1.0837
# Epoch 10/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1230 — val_recall: 0.9293 — val_f1: 0.2172
#  — Class 1 — val_precision: 0.8211 — val_recall: 0.1489 — val_f1: 0.2521
#  — Class 2 — val_precision: 0.0000 — val_recall: 0.0000 — val_f1: 0.0000
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 75ms/step - loss: 1.0935 - val_loss: 1.0716
# Epoch 11/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1188 — val_recall: 0.9545 — val_f1: 0.2113
#  — Class 1 — val_precision: 0.8115 — val_recall: 0.0824 — val_f1: 0.1495
#  — Class 2 — val_precision: 0.0000 — val_recall: 0.0000 — val_f1: 0.0000
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 74ms/step - loss: 1.0760 - val_loss: 1.1206
# Epoch 12/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep -
#  — Class 0 — val_precision: 0.1239 — val_recall: 0.9141 — val_f1: 0.2182
#  — Class 1 — val_precision: 0.8217 — val_recall: 0.1073 — val_f1: 0.1898
#  — Class 2 — val_precision: 0.1562 — val_recall: 0.0478 — val_f1: 0.0732
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 65s 75ms/step - loss: 1.0780 - val_loss: 1.0952
# Epoch 13/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep -
#  — Class 0 — val_precision: 0.1229 — val_recall: 0.2980 — val_f1: 0.1740
#  — Class 1 — val_precision: 0.7694 — val_recall: 0.2388 — val_f1: 0.3644
#  — Class 2 — val_precision: 0.1847 — val_recall: 0.5064 — val_f1: 0.2706
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 75ms/step - loss: 1.0891 - val_loss: 1.0784
# Epoch 14/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1195 — val_recall: 0.9242 — val_f1: 0.2117
#  — Class 1 — val_precision: 0.9268 — val_recall: 0.0632 — val_f1: 0.1184
#  — Class 2 — val_precision: 0.2079 — val_recall: 0.0669 — val_f1: 0.1012
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 65s 76ms/step - loss: 1.0898 - val_loss: 1.1173
# Epoch 15/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - l
#  — Class 0 — val_precision: 0.1271 — val_recall: 0.6616 — val_f1: 0.2132
#  — Class 1 — val_precision: 0.8129 — val_recall: 0.1156 — val_f1: 0.2025
#  — Class 2 — val_precision: 0.1836 — val_recall: 0.2994 — val_f1: 0.2276
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 74ms/step - loss: 1.0599 - val_loss: 1.0844
# Epoch 16/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep -
#  — Class 0 — val_precision: 0.1304 — val_recall: 0.3788 — val_f1: 0.1940
#  — Class 1 — val_precision: 0.7641 — val_recall: 0.1913 — val_f1: 0.3061
#  — Class 2 — val_precision: 0.1838 — val_recall: 0.4904 — val_f1: 0.2674
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 75ms/step - loss: 1.1017 - val_loss: 1.0710
# Epoch 17/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1235 — val_recall: 0.6061 — val_f1: 0.2051
#  — Class 1 — val_precision: 0.7758 — val_recall: 0.1065 — val_f1: 0.1873
#  — Class 2 — val_precision: 0.1958 — val_recall: 0.3599 — val_f1: 0.2536
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 63s 74ms/step - loss: 1.1019 - val_loss: 1.1112
# Epoch 18/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1202 — val_recall: 0.9798 — val_f1: 0.2141
#  — Class 1 — val_precision: 0.9000 — val_recall: 0.0674 — val_f1: 0.1254
#  — Class 2 — val_precision: 0.2000 — val_recall: 0.0064 — val_f1: 0.0123
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 63s 74ms/step - loss: 1.0900 - val_loss: 1.1222
# Epoch 19/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step ep -
#  — Class 0 — val_precision: 0.1247 — val_recall: 0.8788 — val_f1: 0.2185
#  — Class 1 — val_precision: 0.7707 — val_recall: 0.1705 — val_f1: 0.2793
#  — Class 2 — val_precision: 0.0755 — val_recall: 0.0127 — val_f1: 0.0218
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 65s 76ms/step - loss: 1.0890 - val_loss: 1.0976
# Epoch 20/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1247 — val_recall: 0.8384 — val_f1: 0.2171
#  — Class 1 — val_precision: 0.9359 — val_recall: 0.0607 — val_f1: 0.1141
#  — Class 2 — val_precision: 0.1869 — val_recall: 0.1815 — val_f1: 0.1842
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 66s 77ms/step - loss: 1.0866 - val_loss: 1.1530
# Epoch 21/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1338 — val_recall: 0.5101 — val_f1: 0.2120
#  — Class 1 — val_precision: 0.7429 — val_recall: 0.3943 — val_f1: 0.5152
#  — Class 2 — val_precision: 0.1900 — val_recall: 0.1943 — val_f1: 0.1921
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 65s 76ms/step - loss: 1.0865 - val_loss: 1.0812
# Epoch 22/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1216 — val_recall: 0.8434 — val_f1: 0.2126
#  — Class 1 — val_precision: 0.7704 — val_recall: 0.2038 — val_f1: 0.3224
#  — Class 2 — val_precision: 0.2174 — val_recall: 0.0159 — val_f1: 0.0297
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 62s 73ms/step - loss: 1.0972 - val_loss: 1.0802
# Epoch 23/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep
#  — Class 0 — val_precision: 0.2857 — val_recall: 0.1111 — val_f1: 0.1600
#  — Class 1 — val_precision: 0.7711 — val_recall: 0.2130 — val_f1: 0.3338
#  — Class 2 — val_precision: 0.1916 — val_recall: 0.7962 — val_f1: 0.3088
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 65s 75ms/step - loss: 1.0854 - val_loss: 1.0806
# Epoch 24/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep -
#  — Class 0 — val_precision: 0.1279 — val_recall: 0.5808 — val_f1: 0.2097
#  — Class 1 — val_precision: 0.8632 — val_recall: 0.0840 — val_f1: 0.1531
#  — Class 2 — val_precision: 0.1834 — val_recall: 0.4076 — val_f1: 0.2530
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 65s 75ms/step - loss: 1.0715 - val_loss: 1.1266
# Epoch 25/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1255 — val_recall: 0.9141 — val_f1: 0.2207
#  — Class 1 — val_precision: 0.8000 — val_recall: 0.1764 — val_f1: 0.2890
#  — Class 2 — val_precision: 0.1429 — val_recall: 0.0032 — val_f1: 0.0062
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 65s 76ms/step - loss: 1.0701 - val_loss: 1.0822
# Epoch 26/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep -
#  — Class 0 — val_precision: 0.1182 — val_recall: 0.6364 — val_f1: 0.1994
#  — Class 1 — val_precision: 0.7848 — val_recall: 0.1032 — val_f1: 0.1824
#  — Class 2 — val_precision: 0.1776 — val_recall: 0.2771 — val_f1: 0.2164
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 62s 72ms/step - loss: 1.0886 - val_loss: 1.1511
# Epoch 27/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep
#  — Class 0 — val_precision: 0.1209 — val_recall: 0.7576 — val_f1: 0.2085
#  — Class 1 — val_precision: 0.7741 — val_recall: 0.2138 — val_f1: 0.3351
#  — Class 2 — val_precision: 0.1986 — val_recall: 0.0892 — val_f1: 0.1231
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 79s 92ms/step - loss: 1.0993 - val_loss: 1.1004
# Epoch 28/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep
#  — Class 0 — val_precision: 0.1193 — val_recall: 0.9293 — val_f1: 0.2115
#  — Class 1 — val_precision: 0.8636 — val_recall: 0.0790 — val_f1: 0.1448
#  — Class 2 — val_precision: 0.1129 — val_recall: 0.0223 — val_f1: 0.0372
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 74ms/step - loss: 1.0649 - val_loss: 1.1423
# Epoch 29/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - l
#  — Class 0 — val_precision: 0.1237 — val_recall: 0.7222 — val_f1: 0.2112
#  — Class 1 — val_precision: 0.7662 — val_recall: 0.1963 — val_f1: 0.3126
#  — Class 2 — val_precision: 0.1720 — val_recall: 0.1369 — val_f1: 0.1525
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 75ms/step - loss: 1.0846 - val_loss: 1.0971
# Epoch 30/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1194 — val_recall: 0.7576 — val_f1: 0.2063
#  — Class 1 — val_precision: 0.7816 — val_recall: 0.1131 — val_f1: 0.1977
#  — Class 2 — val_precision: 0.1972 — val_recall: 0.1783 — val_f1: 0.1873
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 75ms/step - loss: 1.0872 - val_loss: 1.1086
# Epoch 31/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step ep
#  — Class 0 — val_precision: 0.1211 — val_recall: 0.7424 — val_f1: 0.2082
#  — Class 1 — val_precision: 0.8092 — val_recall: 0.1023 — val_f1: 0.1817
#  — Class 2 — val_precision: 0.1753 — val_recall: 0.1943 — val_f1: 0.1843
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 63s 74ms/step - loss: 1.0745 - val_loss: 1.1211
# Epoch 32/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep -
#  — Class 0 — val_precision: 0.1191 — val_recall: 0.9444 — val_f1: 0.2115
#  — Class 1 — val_precision: 0.8559 — val_recall: 0.0790 — val_f1: 0.1447
#  — Class 2 — val_precision: 0.2121 — val_recall: 0.0223 — val_f1: 0.0403
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 65s 76ms/step - loss: 1.0787 - val_loss: 1.1103
# Epoch 33/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1204 — val_recall: 0.8586 — val_f1: 0.2112
#  — Class 1 — val_precision: 0.7727 — val_recall: 0.1273 — val_f1: 0.2186
#  — Class 2 — val_precision: 0.1827 — val_recall: 0.0605 — val_f1: 0.0909
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 74ms/step - loss: 1.0890 - val_loss: 1.1273
# Epoch 34/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep -
#  — Class 0 — val_precision: 0.1218 — val_recall: 0.9242 — val_f1: 0.2152
#  — Class 1 — val_precision: 0.8582 — val_recall: 0.0957 — val_f1: 0.1722
#  — Class 2 — val_precision: 0.1948 — val_recall: 0.0478 — val_f1: 0.0767
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 63s 73ms/step - loss: 1.0776 - val_loss: 1.0969
# Epoch 35/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep -
#  — Class 0 — val_precision: 0.1199 — val_recall: 0.7576 — val_f1: 0.2070
#  — Class 1 — val_precision: 0.7291 — val_recall: 0.1814 — val_f1: 0.2905
#  — Class 2 — val_precision: 0.1768 — val_recall: 0.0924 — val_f1: 0.1213
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 66s 77ms/step - loss: 1.0740 - val_loss: 1.0896
# Epoch 36/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1172 — val_recall: 0.7828 — val_f1: 0.2039
#  — Class 1 — val_precision: 0.7065 — val_recall: 0.1822 — val_f1: 0.2897
#  — Class 2 — val_precision: 0.1463 — val_recall: 0.0382 — val_f1: 0.0606
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 68s 79ms/step - loss: 1.0561 - val_loss: 1.1186
# Epoch 37/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1234 — val_recall: 0.6667 — val_f1: 0.2082
#  — Class 1 — val_precision: 0.7350 — val_recall: 0.2953 — val_f1: 0.4214
#  — Class 2 — val_precision: 0.1677 — val_recall: 0.0860 — val_f1: 0.1137
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 67s 78ms/step - loss: 1.0769 - val_loss: 1.1170
# Epoch 38/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1205 — val_recall: 0.8838 — val_f1: 0.2121
#  — Class 1 — val_precision: 0.8013 — val_recall: 0.1040 — val_f1: 0.1841
#  — Class 2 — val_precision: 0.1509 — val_recall: 0.0510 — val_f1: 0.0762
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 66s 77ms/step - loss: 1.0591 - val_loss: 1.1052
# Epoch 39/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep -
#  — Class 0 — val_precision: 0.1140 — val_recall: 0.6515 — val_f1: 0.1940
#  — Class 1 — val_precision: 0.7096 — val_recall: 0.2338 — val_f1: 0.3517
#  — Class 2 — val_precision: 0.1774 — val_recall: 0.1051 — val_f1: 0.1320
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 74ms/step - loss: 1.0707 - val_loss: 1.1033
# Epoch 40/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1184 — val_recall: 0.8636 — val_f1: 0.2083
#  — Class 1 — val_precision: 0.8532 — val_recall: 0.0774 — val_f1: 0.1419
#  — Class 2 — val_precision: 0.2050 — val_recall: 0.1051 — val_f1: 0.1389
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 75ms/step - loss: 1.0769 - val_loss: 1.1458
# Epoch 41/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1184 — val_recall: 0.7323 — val_f1: 0.2038
#  — Class 1 — val_precision: 0.7958 — val_recall: 0.1265 — val_f1: 0.2182
#  — Class 2 — val_precision: 0.1946 — val_recall: 0.1847 — val_f1: 0.1895
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 65s 75ms/step - loss: 1.0644 - val_loss: 1.1189
# Epoch 42/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep -
#  — Class 0 — val_precision: 0.1230 — val_recall: 0.6919 — val_f1: 0.2088
#  — Class 1 — val_precision: 0.7128 — val_recall: 0.2354 — val_f1: 0.3540
#  — Class 2 — val_precision: 0.1773 — val_recall: 0.1146 — val_f1: 0.1393
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 64s 75ms/step - loss: 1.0797 - val_loss: 1.0798
# Epoch 43/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep -
#  — Class 0 — val_precision: 0.1220 — val_recall: 0.7828 — val_f1: 0.2110
#  — Class 1 — val_precision: 0.7201 — val_recall: 0.2055 — val_f1: 0.3197
#  — Class 2 — val_precision: 0.1600 — val_recall: 0.0510 — val_f1: 0.0773
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 65s 76ms/step - loss: 1.0752 - val_loss: 1.1147
# Epoch 44/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step ep -
#  — Class 0 — val_precision: 0.1200 — val_recall: 0.6313 — val_f1: 0.2016
#  — Class 1 — val_precision: 0.7569 — val_recall: 0.1606 — val_f1: 0.2649
#  — Class 2 — val_precision: 0.1775 — val_recall: 0.2357 — val_f1: 0.2025
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 67s 78ms/step - loss: 1.0790 - val_loss: 1.1238
# Epoch 45/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1232 — val_recall: 0.8535 — val_f1: 0.2153
#  — Class 1 — val_precision: 0.8256 — val_recall: 0.1181 — val_f1: 0.2067
#  — Class 2 — val_precision: 0.1706 — val_recall: 0.0924 — val_f1: 0.1198
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 66s 77ms/step - loss: 1.0784 - val_loss: 1.1235
# Epoch 46/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep -
#  — Class 0 — val_precision: 0.1208 — val_recall: 0.7980 — val_f1: 0.2098
#  — Class 1 — val_precision: 0.7401 — val_recall: 0.1872 — val_f1: 0.2988
#  — Class 2 — val_precision: 0.1373 — val_recall: 0.0446 — val_f1: 0.0673
# 857/857 ━━━━━━━━━━━━━━━━━━━━ 65s 76ms/step - loss: 1.0868 - val_loss: 1.1095
# Epoch 47/50
# 759/857 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 1.0824
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 5
#       2 metrics = Metrics(validation_data=(X_val, y_val))
#       4 # Train the model with the custom metrics callback and class weights
# ----> 5 history = model.fit(X_train, y_train, epochs=50, batch_size=16, shuffle=True, validation_data=(X_val, y_val), verbose=1, callbacks=[metrics], class_weight=class_weights)
#
# File ~/mambaforge/envs/ml4qs/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/mambaforge/envs/ml4qs/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File ~/mambaforge/envs/ml4qs/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/mambaforge/envs/ml4qs/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/mambaforge/envs/ml4qs/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/mambaforge/envs/ml4qs/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/mambaforge/envs/ml4qs/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/mambaforge/envs/ml4qs/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/mambaforge/envs/ml4qs/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/mambaforge/envs/ml4qs/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~/mambaforge/envs/ml4qs/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# Evaluate the model
y_pred = np.argmax(model.predict(X_test), axis=1)

# Calculate precision, recall, and F1 score for the test set for each class
precision = precision_score(y_test, y_pred, average=None)
recall = recall_score(y_test, y_pred, average=None)
f1 = f1_score(y_test, y_pred, average=None)

print("Test Precision for each class:", precision)
print("Test Recall for each class:", recall)
print("Test F1 Score for each class:", f1)
# Out:
# 108/108 [==============================] - 0s 2ms/step
# Test Precision for each class: [0.08619092 0.85653409 0.16135881]
# Test Recall for each class: [0.37804878 0.44014599 0.34311512]
# Test F1 Score for each class: [0.14037736 0.58148505 0.21949458]
