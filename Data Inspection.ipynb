# %%
import pandas as pd
import os

# show all csv files one by one in current directory
dfs = []
names = []
path = "Raw Data"
for file in os.listdir(path):
    if file.endswith(".csv"):
        print(file)
        df = pd.read_csv(os.path.join(path, file))
        dfs.append(df)
        names.append(file)
        #print statistical analysis of the data
        print(df.describe())

        #save as .txt file
        df.describe().to_csv("Data Stats/" + file + ".txt", sep='\t', encoding='utf-8')
        print("\n\n\n\n")
# Out:
# Resting Heart Rate 2.csv
#        Resting Heart Rate (count/min)
# count                      714.000000
# mean                        71.208683
# std                          6.797812
# min                         47.000000
# 25%                         67.000000
# 50%                         71.000000
# 75%                         75.000000
# max                         94.000000
#
#
#
#
#
# Environmental Audio Exposure 2.csv
#        Environmental Audio Exposure (dBASPL)
# count                           13919.000000
# mean                               69.576667
# std                                 9.467445
# min                                33.330000
# 25%                                64.685000
# 50%                                69.890000
# 75%                                75.165000
# max                               106.040000
#
#
#
#
#
# Walking Speed 2.csv
#        Walking Speed (km/hr)
# count           18920.000000
# mean                4.486462
# ...

# %%
import matplotlib.pyplot as plt
# Show histograms for each column
for i, df in enumerate(dfs):
    df.hist(bins=20)
    #save histogram with name of the .csv file
    plt.savefig("Data Figures/"+ names[i] + ".png")

# %%
import numpy as np

maxTimeDelta = 2

instances = []

heartRateDf = pd.read_csv("Raw Data/Heart Rate 2.csv")
#convert time to datetime
heartRateDf["Date/Time"] = pd.to_datetime(heartRateDf["Date/Time"])
for df in dfs:
    df["Date/Time"] = pd.to_datetime(df["Date/Time"])
for i, row in heartRateDf.iterrows():
    currTimeStamp = row["Date/Time"]

    for df in dfs:
        #create empty array of shape []
        currInstance = np.empty()
        currInstanceMissingVals = []
        for j, row2 in df.iterrows():
            if abs(row2["Date/Time"] - currTimeStamp).minutes < maxTimeDelta:
                #currInstance.append((row2, row))
# Out:
# 2022-01-31 21:37:00
# 2022-01-31 21:39:00
# 2022-01-31 21:46:00
# 2022-01-31 21:50:00
# 2022-01-31 21:55:00
# 2022-01-31 21:56:00
# 2022-01-31 22:07:00
# 2022-01-31 22:10:00
# 2022-01-31 22:15:00
# 2022-01-31 22:21:00
# 2022-01-31 22:28:00
# 2022-01-31 22:31:00
# 2022-01-31 22:34:00
# 2022-01-31 22:48:00
# 2022-01-31 22:50:00
# 2022-01-31 22:57:00
# 2022-01-31 23:05:00
# 2022-01-31 23:11:00
# 2022-01-31 23:17:00
# 2022-01-31 23:23:00
# 2022-01-31 23:27:00
# 2022-01-31 23:31:00
# 2022-01-31 23:35:00
# 2022-01-31 23:39:00
# 2022-01-31 23:49:00
# 2022-01-31 23:51:00
# 2022-01-31 23:57:00
# 2022-02-01 00:02:00
# 2022-02-01 00:07:00
# 2022-02-01 00:11:00
# 2022-02-01 00:19:00
# 2022-02-01 00:23:00
# 2022-02-01 00:24:00
# 2022-02-01 11:34:00
# 2022-02-01 11:37:00
# 2022-02-01 11:40:00
# 2022-02-01 11:45:00
# 2022-02-01 11:50:00
# 2022-02-01 12:03:00
# 2022-02-01 12:06:00
# 2022-02-01 12:10:00
# 2022-02-01 12:11:00
# 2022-02-01 12:18:00
# 2022-02-01 12:23:00
# 2022-02-01 12:29:00
# ...
